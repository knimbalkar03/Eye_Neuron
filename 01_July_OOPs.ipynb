# %% [raw]
# 1. What is the primary goal of Object-Oriented Programming (OOP)?
#
# The primary goal of Object-Oriented Programming (OOP) is to organize software in a manner that mimics real-world objects or concepts, making it easier to create, maintain, and scale complex systems. OOP achieves this by representing data and behavior as objects that interact with each other.
# Key principles of OOP include:
# Encapsulation
# Inheritance
# Polymorphism
# Abstraction

# %% [raw]
# 2. What is an object in Python?
#
# In Python, an object is a fundamental concept that represents a specific instance of a data structure or class. Everything in Python is an object, including integers, strings, lists, functions, and even classes themselves.
# An object in Python consists of both data (attributes) and methods (functions) that operate on the data. These attributes and methods are accessed using dot notation (object.attribute or object.method()).

# %% [raw]
# 3. What is a class in Python?
#
#
# In Python, a class is a blueprint or template for creating objects. It serves as a way to define the characteristics (attributes) and behaviors (methods) that objects of that class will have.
# Attributes are variables that hold data associated with the class or its instances, while methods are functions that perform actions or operations on the data within the class or its instances.

# %% [raw]
# 4. What are attributes and methods in a class?
#
# In a class, attributes and methods are the building blocks that define the characteristics and behaviors of objects created from that class.
# Attributes:
# Attributes are variables that hold data associated with the class or its instances (objects).
# They represent the state of the object and define its properties.
# Attributes are defined within the class and are accessed using dot notation (object.attribute).
# Each object of the class has its own set of attribute values.
# Attributes can be initialized in the constructor (__init__ method) or can be added dynamically.
# Methods:
# Methods are functions defined within a class that operate on the object's data.
# They represent the behaviors or actions that objects of the class can perform.
# Methods take at least one parameter, conventionally named self, which refers to the instance of the class.
# Methods are accessed using dot notation (object.method()).
# They can interact with the object's attributes and modify their values.
# Methods can be classified as instance methods, class methods, or static methods based on their behavior.

# %% [raw]
# 5. What is the difference between class variables and instance variables in Python?
#
# In Python, class variables and instance variables are two types of variables used within a class, but they serve different purposes and have different scopes.
#
# 1. Class Variables:
#
# Class variables are variables that are shared among all instances (objects) of a class.
# They are defined within the class but outside of any methods.
# Class variables are accessed using the class name itself (ClassName.variable).
# They are typically used to store data that is common to all instances of the class.
# Modifications to class variables affect all instances of the class.
#
# 2. Instance Variables:
#
# Instance variables are variables that are unique to each instance (object) of a class.
# They are defined within methods using the self keyword within the constructor (__init__) or any other method.
# Instance variables are accessed using the object name (object.variable) or self within methods.
# They store data specific to each object and can have different values for each instance.
# Modifications to instance variables affect only the specific instance they belong to.

# %% [raw]
# 6. What is the purpose of the self parameter in Python class methods?
#
# In Python, the self parameter in class methods serves as a reference to the instance of the class itself. It allows methods to access and manipulate instance-specific data (attributes) and call other methods within the class. It's crucial for working with instance variables and maintaining the state of objects across method calls.

# %%
7.

class Book:
    def __init__(self, title, author, isbn, publication_year, available_copies):
        self.title = title
        self.author = author
        self.isbn = isbn
        self.publication_year = publication_year
        self.available_copies = available_copies

    def check_out(self):
        if self.available_copies > 0:
            self.available_copies -= 1
            print(f"Book '{self.title}' checked out successfully.")
        else:
            print(f"Sorry, no copies of '{self.title}' available for checkout.")

    def return_book(self):
        self.available_copies += 1
        print(f"Book '{self.title}' returned successfully.")

    def display_book_info(self):
        print("Book Information:")
        print(f"Title: {self.title}")
        print(f"Author(s): {self.author}")
        print(f"ISBN: {self.isbn}")
        print(f"Publication Year: {self.publication_year}")
        print(f"Available Copies: {self.available_copies}")


# Example usage:
if __name__ == "__main__":
    # Creating a book object
    book1 = Book("The Great Gatsby", "F. Scott Fitzgerald", "9780743273565", 1925, 3)

    # Displaying book information
    book1.display_book_info()

    # Checking out a book
    book1.check_out()
    book1.check_out()
    book1.check_out()
    book1.check_out()  # Trying to check out when no copies are available

    # Returning a book
    book1.return_book()

    # Displaying updated book information
    book1.display_book_info()
# Out:
# Book Information:
# Title: The Great Gatsby
# Author(s): F. Scott Fitzgerald
# ISBN: 9780743273565
# Publication Year: 1925
# Available Copies: 3
# Book 'The Great Gatsby' checked out successfully.
# Book 'The Great Gatsby' checked out successfully.
# Book 'The Great Gatsby' checked out successfully.
# Sorry, no copies of 'The Great Gatsby' available for checkout.
# Book 'The Great Gatsby' returned successfully.
# Book Information:
# Title: The Great Gatsby
# Author(s): F. Scott Fitzgerald
# ISBN: 9780743273565
# Publication Year: 1925
# Available Copies: 1

# %%
8.

class Ticket:
    def __init__(self, ticket_id, event_name, event_date, venue, seat_number, price):
        self.ticket_id = ticket_id
        self.event_name = event_name
        self.event_date = event_date
        self.venue = venue
        self.seat_number = seat_number
        self.price = price
        self.is_reserved = False

    def reserve_ticket(self):
        if not self.is_reserved:
            self.is_reserved = True
            print("Ticket reserved successfully.")
        else:
            print("Ticket is already reserved.")

    def cancel_reservation(self):
        if self.is_reserved:
            self.is_reserved = False
            print("Reservation canceled successfully.")
        else:
            print("Ticket is not reserved.")

    def display_ticket_info(self):
        print("Ticket Information:")
        print(f"Ticket ID: {self.ticket_id}")
        print(f"Event Name: {self.event_name}")
        print(f"Event Date: {self.event_date}")
        print(f"Venue: {self.venue}")
        print(f"Seat Number: {self.seat_number}")
        print(f"Price: {self.price}")
        print(f"Reservation Status: {'Reserved' if self.is_reserved else 'Not Reserved'}")


# Example usage:
if __name__ == "__main__":
    # Creating a ticket object
    ticket1 = Ticket("123456", "Concert", "2024-04-15", "Stadium A", "A25", 50.00)

    # Displaying ticket information
    ticket1.display_ticket_info()

    # Reserving a ticket
    ticket1.reserve_ticket()
    ticket1.reserve_ticket()  # Trying to reserve again

    # Canceling reservation
    ticket1.cancel_reservation()

    # Displaying updated ticket information
    ticket1.display_ticket_info()
# Out:
# Ticket Information:
# Ticket ID: 123456
# Event Name: Concert
# Event Date: 2024-04-15
# Venue: Stadium A
# Seat Number: A25
# Price: 50.0
# Reservation Status: Not Reserved
# Ticket reserved successfully.
# Ticket is already reserved.
# Reservation canceled successfully.
# Ticket Information:
# Ticket ID: 123456
# Event Name: Concert
# Event Date: 2024-04-15
# Venue: Stadium A
# Seat Number: A25
# Price: 50.0
# Reservation Status: Not Reserved

# %%
9.

class ShoppingCart:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)
        print(f"Item '{item}' added to the shopping cart.")

    def remove_item(self, item):
        if item in self.items:
            self.items.remove(item)
            print(f"Item '{item}' removed from the shopping cart.")
        else:
            print(f"Item '{item}' not found in the shopping cart.")

    def view_cart(self):
        if self.items:
            print("Items in the shopping cart:")
            for item in self.items:
                print(item)
        else:
            print("Shopping cart is empty.")

    def clear_cart(self):
        self.items = []
        print("Shopping cart cleared.")


# Example usage:
if __name__ == "__main__":
    # Creating a shopping cart object
    cart = ShoppingCart()

    # Adding items to the cart
    cart.add_item("Laptop")
    cart.add_item("Headphones")
    cart.add_item("Phone")

    # Viewing the cart
    cart.view_cart()

    # Removing an item from the cart
    cart.remove_item("Headphones")

    # Clearing the cart
    cart.clear_cart()

    # Viewing the cart after clearing
    cart.view_cart()
# Out:
# Item 'Laptop' added to the shopping cart.
# Item 'Headphones' added to the shopping cart.
# Item 'Phone' added to the shopping cart.
# Items in the shopping cart:
# Laptop
# Headphones
# Phone
# Item 'Headphones' removed from the shopping cart.
# Shopping cart cleared.
# Shopping cart is empty.

# %%
10.

class Student:
    def __init__(self, name, age, grade, student_id):
        self.name = name
        self.age = age
        self.grade = grade
        self.student_id = student_id
        self.attendance = {}  # Dictionary to store attendance records (date: status)

    def update_attendance(self, date, status):
        self.attendance[date] = status

    def get_attendance(self):
        return self.attendance

    def get_average_attendance(self):
        total_days = len(self.attendance)
        if total_days == 0:
            return 0  # Return 0 if attendance record is empty
        present_days = sum(1 for status in self.attendance.values() if status == "present")
        return (present_days / total_days) * 100  # Calculate and return average attendance percentage


# Example usage:
if __name__ == "__main__":
    # Creating a student object
    student1 = Student("John Doe", 15, 10, "2023001")

    # Updating attendance
    student1.update_attendance("2024-03-15", "present")
    student1.update_attendance("2024-03-16", "absent")
    student1.update_attendance("2024-03-17", "present")

    # Getting attendance record
    print("Attendance Record:")
    print(student1.get_attendance())

    # Getting average attendance
    average_attendance = student1.get_average_attendance()
    print(f"Average Attendance: {average_attendance:.2f}%")
# Out:
# Attendance Record:
# {'2024-03-15': 'present', '2024-03-16': 'absent', '2024-03-17': 'present'}
# Average Attendance: 66.67%
